# %%
import requests
import matplotlib.pyplot as plt

RECEIPT_NUMBER_BASE = "EAC209006"
RANGE_START = 3785
RANGE_END = 3985
CASE_TYPE = 'I-539'


def checkStatus(ReceiptNum, statusList):
    pload = {"appReceiptNum": ReceiptNum, "initCaseSearch":"CHECK STATUS"}
    r = requests.post('https://egov.uscis.gov/casestatus/mycasestatus.do',data = pload)
    response = r.text.split("\n")
    if CASE_TYPE in response[733]:
        statusList.append((ReceiptNum, response[719].strip()))
        
def savePlot(statusList):
    x, y = zip(*statusList)
    plt.scatter(x, y)
    plt.show()
        
num_digits = len(str(RANGE_END))
statusList = []
for i in range(RANGE_START, RANGE_END):
    ReceiptNum = RECEIPT_NUMBER_BASE + str(i).zfill(num_digits)
    checkStatus(ReceiptNum, statusList)
savePlot(statusList)

# %%
len(statusList)
# Out:
# 87

# %%
statusList
# Out:
# [('EAC2090063796', 'Case Was Received'),
#  ('EAC2090063797', 'Date of Birth Was Updated'),
#  ('EAC2090063798', 'Fingerprint Fee Was Received'),
#  ('EAC2090063799', 'Case Was Denied'),
#  ('EAC2090063800', 'Case Was Approved'),
#  ('EAC2090063801', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063802', 'Fingerprint Fee Was Received'),
#  ('EAC2090063803', 'Fingerprint Fee Was Received'),
#  ('EAC2090063816', 'Case Was Approved'),
#  ('EAC2090063817', 'Fingerprint Fee Was Received'),
#  ('EAC2090063818', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063820', 'Case Was Approved'),
#  ('EAC2090063821', 'Case Was Approved'),
#  ('EAC2090063822', 'Case Was Approved'),
#  ('EAC2090063823', 'Fingerprint Fee Was Received'),
#  ('EAC2090063825', 'Fingerprint Fee Was Received'),
#  ('EAC2090063826', 'Case Was Approved'),
#  ('EAC2090063828', 'Withdrawal Acknowledgement Notice Was Sent'),
#  ('EAC2090063829', 'Case Was Approved'),
#  ('EAC2090063830', 'Case Was Denied'),
#  ('EAC2090063835', 'Case Was Rejected Because It Was Improperly Filed'),
#  ('EAC2090063845', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063846', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063847', 'Case Was Approved'),
#  ('EAC2090063848', 'Fingerprint Fee Was Received'),
#  ('EAC2090063849', 'Case Was Approved'),
#  ('EAC2090063850', 'Case Was Denied'),
#  ('EAC2090063851',
#   'Notice Was Returned To USCIS Because The Post Office Could Not Deliver It'),
#  ('EAC2090063852', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063853', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063854', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063855', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063856', 'Case Was Approved'),
#  ('EAC2090063857', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063858', 'Fingerprint Fee Was Received'),
#  ('EAC2090063859', 'Case Was Approved'),
#  ('EAC2090063860', 'Fingerprint Fee Was Received'),
#  ('EAC2090063861', 'Fingerprint Fee Was Received'),
#  ('EAC2090063862', 'Fingerprint Fee Was Received'),
#  ('EAC2090063863', 'Case Was Approved'),
#  ('EAC2090063864', 'Case Was Denied'),
#  ('EAC2090063865', 'Case Was Denied'),
#  ('EAC2090063866', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063867', 'Fingerprint Fee Was Received'),
#  ('EAC2090063869', 'Case Was Denied'),
#  ('EAC2090063870', 'Case Was Approved'),
#  ('EAC2090063871', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063872', 'Case Was Approved'),
#  ('EAC2090063875', 'Correspondence Was Received And USCIS Is Reviewing It'),
#  ('EAC2090063878', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063879', 'Case Was Approved'),
#  ('EAC2090063882', 'Expedite Request Denied'),
#  ('EAC2090063886', 'Expedite Request Denied'),
#  ('EAC2090063888',
#   'Notice Was Returned To USCIS Because The Post Office Could Not Deliver It'),
#  ('EAC2090063889', 'Case Was Approved'),
#  ('EAC2090063891', 'Fingerprint Fee Was Received'),
#  ('EAC2090063893', 'Fingerprint Fee Was Received'),
#  ('EAC2090063900', 'Fingerprint Fee Was Received'),
#  ('EAC2090063901', 'Case Was Approved'),
#  ('EAC2090063902', 'Fingerprint Fee Was Received'),
#  ('EAC2090063903', 'Fingerprint Fee Was Received'),
#  ('EAC2090063904',
#   'Notice Was Returned To USCIS Because The Post Office Could Not Deliver It'),
#  ('EAC2090063927', 'Fingerprint Fee Was Received'),
#  ('EAC2090063930', 'Fingerprint Fee Was Received'),
#  ('EAC2090063931', 'Fingerprint Fee Was Received'),
#  ('EAC2090063932', 'Case Was Denied'),
#  ('EAC2090063933', 'Case Was Approved'),
#  ('EAC2090063941', 'Fingerprint Fee Was Received'),
#  ('EAC2090063942', 'Case Was Approved'),
#  ('EAC2090063943', 'Fingerprint Fee Was Received'),
#  ('EAC2090063944', 'Fingerprint Fee Was Received'),
#  ('EAC2090063945', 'Fingerprint Fee Was Received'),
#  ('EAC2090063955', 'Fingerprint Fee Was Received'),
#  ('EAC2090063956', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063960', 'Case Was Denied'),
#  ('EAC2090063961', 'Case Was Approved'),
#  ('EAC2090063962', 'Case Was Approved'),
#  ('EAC2090063969', 'Fingerprint Fee Was Received'),
#  ('EAC2090063971', 'Case Was Denied'),
#  ('EAC2090063972', 'Case Was Rejected Because It Was Improperly Filed'),
#  ('EAC2090063973', 'Case Was Approved'),
#  ('EAC2090063974', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063975', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063976', 'Case Was Approved'),
#  ('EAC2090063980', 'Case Was Updated To Show Fingerprints Were Taken'),
#  ('EAC2090063981', 'Request for Additional Evidence Was Sent'),
#  ('EAC2090063982', 'Case Was Received')]
